# %% [markdown]
#  string are the sequence of characters

# %% [markdown]
#  in python speacifically strings are a sequence of unicode characters

# %% [markdown]
# # Creating strings

# %%
s='hello'
s="hello"
s='''hello'''
s="""hello"""
s=str('hello')
print(s)
# Out:
# hello

# %%
"it's raining today"
# Out:
# "it's raining today"

# %% [markdown]
# # Accessing Substrings from a strings

# %%
# positive indexing   start with 0
s='hello world'
print(s[1])
print(s[5])
# Out:
# e

# %%
# negative indexing  start with -1
s='hello world'
print(s[-1])
print(s[-2])
# Out:
# d
# l

# %%
#slicing
s='hello world'
print(s[0:5])
print(s[2:])
print(s[:4])
print(s[:])
print(s[0:6:2])
print(s[0:6:3])
print(s[6:0:-1])   #first number should be greater
print(s[6:0:-2])
# Out:
# hello
# llo world
# hell
# hello world
# hlo
# hl
# w olle
# wol

# %%
#reverse string
print(s[::-1])
# Out:
# dlrow olleh

# %%
s='hello world'
print(s[-5:])
print(s[-1:-6:-1])
# Out:
# world
# dlrow

# %% [markdown]
# # Editing and Deleting in string

# %%
# s='hello world'
# s[0]='H'
#  Python strings are immutable can not edit

# %%
# s='hello world'
# del s
# print(s)

# %%
# s='hello world'
# del s[-1:-5:2]
# print(s)
#  'str' object does not support item deletion

# %% [markdown]
# # operations on string

# %% [markdown]
# Arithmetic operators(+ , *)

# %%
print('delhi' + ' ' + 'mumbai')
# Out:
# delhi mumbai

# %%
print('delhi'*5)
# Out:
# delhidelhidelhidelhidelhi

# %%
print("*"*50)
# Out:
# **************************************************

# %% [markdown]
# relational operator(==,>,<,<=,>=,!=)

# %%
'delhi' == 'mumbai'
# Out:
# False

# %%
'delhi' != 'mumbai'
# Out:
# True

# %%
'mumbai' > 'pune'
#lexiographically(base on squence in dictonary)
# Out:
# False

# %%
'Pune' > 'pune'
# Out:
# False

# %% [markdown]
# logical operators  (empty=false and full=true)

# %%
'hello' and 'world'
# Out:
# 'world'

# %%
'hello' or 'world'
# Out:
# 'hello'

# %%
'' and 'world'
# Out:
# ''

# %%
'' or 'world'
# Out:
# 'world'

# %%
not ''
# Out:
# True

# %%
not 'hello'
# Out:
# False

# %%
for i in 'hello':
  print(i)
# Out:
# h
# e
# l
# l
# o

# %%
for i in 'delhi':
     print('pune')
# Out:
# pune
# pune
# pune
# pune
# pune

# %% [markdown]
# #memebership operator

# %%
'D' in 'delhi'
# Out:
# False

# %%
'D' in 'Delhi'
# Out:
# True

# %%
'D' not in 'delhi'
# Out:
# True

# %%
'd' not in 'delhi'
# Out:
# False

# %% [markdown]
# # String Functions

# %% [markdown]
# len

# %%
len('hello world')
# Out:
# 11

# %% [markdown]
# max

# %%
max('hello world')
# Out:
# 'w'

# %% [markdown]
# min

# %%
min('hello world')
# Out:
# ' '

# %% [markdown]
# sorted

# %%
sorted('hello world')
# Out:
# [' ', 'd', 'e', 'h', 'l', 'l', 'l', 'o', 'o', 'r', 'w']

# %% [markdown]
# # Capitalize/Title/Upper/Lower/Swapcase

# %%
s='hello world'
print(s.capitalize())
print(s)
# Out:
# Hello world
# hello world

# %%
s='hello world'
s.title()
# Out:
# 'Hello World'

# %%
s='hello world'
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s='HELLO WORLD'
s.lower()
# Out:
# 'hello world'

# %%
'HELLO WORLD'.swapcase()
# Out:
# 'hello world'

# %%
'hello world'.swapcase()
# Out:
# 'HELLO WORLD'

# %% [markdown]
# # Count/Find/Index

# %%
'my name is nitish'.count('i')  # how many time i occured in string
# Out:
# 3

# %%
'my name is nitish'.find('is')    #find index of specific substring
# Out:
# 8

# %%
'my name is nitish'.find('x')
# Out:
# -1

# %%
'my name is nitish'.index('is')
# Out:
# 8

# %%
# 'my name is nitish'.index('x')
#throw error

# %% [markdown]
# # endswith/startswith(utility functions)

# %%
'my name is nitish'.endswith('sho')
# Out:
# False

# %%
'my name is nitish'.startswith('my')
# Out:
# True

# %% [markdown]
# # format

# %%
name='nitish'
gender='male'
'Hi my name is {} and I am a {}'.format(name,gender)
# Out:
# 'Hi my name is nitish and I am a male'

# %%
name='nitish'
gender='male'
'Hi my name is {1} and I am a {0}'.format(name,gender)
# Out:
# 'Hi my name is male and I am a nitish'

# %% [markdown]
# # isalnum/isalpha/isdigit/isidentifier

# %%
'nitish1234'.isalnum()
# Out:
# True

# %%
'nitish1234&'.isalnum()
# Out:
# False

# %%
'saniya'.isalpha()
# Out:
# True

# %%
'saniya123'.isalpha()
# Out:
# False

# %%
'saniya'.isdigit()
# Out:
# False

# %%
'123'.isdigit()
# Out:
# True

# %%
'1name'.isidentifier()
# Out:
# False

# %%
'name'.isidentifier()
# Out:
# True

# %%
'first_name'.isidentifier()
# Out:
# True

# %%
'first-name'.isidentifier()
# Out:
# False

# %% [markdown]
# # split/join

# %%
'hi my name is saniya'.split()
# Out:
# ['hi', 'my', 'name', 'is', 'saniya']

# %%
'hi my name is saniya'.split('i')
# Out:
# ['h', ' my name ', 's san', 'ya']

# %%
" ".join(['hi', 'my', 'name', 'is', 'saniya'])
# Out:
# 'hi my name is saniya'

# %%
"-".join(['hi', 'my', 'name', 'is', 'saniya'])
# Out:
# 'hi-my-name-is-saniya'

# %% [markdown]
# # replace

# %%
'hi my name is saniya'.replace('saniya','najiya')
# Out:
# 'hi my name is najiya'

# %% [markdown]
# # strip

# %%
'saniya             '.strip()
# Out:
# 'saniya'

# %% [markdown]
# # practice example

# %%
# find length of string without using len() function
s=input("enter the string")
counter=0
for i in s:
    # print(i)
    counter+=1
print("length of string is",counter)
# Out:
# enter the string saniya
# length of string is 6

# %%
# Extract username from a given email.
# Eg if the email is nitish24singh@gmail.com
# then the username should be nitish24singh

s=input('enter the email')
print(s.index('@'))
pos=s.index('@')
print(s[0:pos])
# Out:
# enter the email  nitish24singh@gmail.com
# 14
#  nitish24singh

# %%
# Count the frequency of a particular character in a provided string.
# Eg 'hello how are you' is the string, the frequency of h in this string is 2.
s=input('enter the string') 
term=input('what would you like to search for')
# s.count('h')
counter=0
for i in s:
  if i==term:
    counter+=1
print(counter)
# Out:
# hello how are you hello how are you
# what would you like to search for h
# 2

# %%
# Write a program which can remove a particular character from a string.
s=input('enter the string') 
term=input('what would you like to remove ')
result=''
for i in s:
    if i!=term:
        result=result+i
print(result)
# Out:
# enter the string saniya
# what would you like to remove  i
# sanya

# %%
# Write a program that can check whether a given string is palindrome or not.
s=input('enter the string') 
result=s[::-1]
if s==result:
    print("palindrome")
else:
    print("not and palindrome")
# Out:
# enter the string madam
# palindrome

# %%
s=input('enter the string') 

for i in range(0,len(s)//2):
   if s[i]!=s[len(s)-i-1]:
     flag=False
     print("not a palindrome")
     break
if flag:
    print(" palindrome")
# Out:
# enter the string saniya
# not a palindrome

# %%
# Write a program to count the number of words in a string without split()
s=input('enter the string')
L=[]
temp=' '
for i in s:
    if i!=' ':
        temp=temp+i
    else:
        L.append(temp)
        temp=' '
L.append(temp)
print(L)
# Out:
# enter the string hi how are you
# [' hi', ' how', ' are', ' you']

# %%
# write a puthon program to convert a string to title case without using the title()
s=input('enter the string')
for i in s.split():
    print(i[0].upper()+i[1:].lower())
# Out:
# enter the string hi how are you
# Hi
# How
# Are
# You

# %%
s=input('enter the string')
L=[]
for i in s.split():
    L.append(i[0].upper()+i[1:].lower())
print(" ".join(L))
# Out:
# enter the string  hi how are you
# Hi How Are You

# %%
#write a program that can convert an ineger to string
number=int(input("enter the number"))
digits='0123456789'
result=''
while number!=0:
    result=digits[number %10]+result
    number=number//10
print(result)
print(type(result))
# Out:
# enter the number 345
# 345
# <class 'str'>
